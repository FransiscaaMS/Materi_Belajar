# %% [markdown]
# Nama: Fransisca Mulya Sari
#
# Kelas : PYTN KS 014
#
# Kode Peserta : PYTN - KS014 - 011
#
# --------------------------------------------------------------

# %% [markdown]
# # ASSIGNMENT PYTHON 1
# - Pada assignment 1 ini, tugasnya adalah membuat visualisasi data dengan projects rubric sebagai berikut.
#
# **Code Review**
#
# |Criteria|Meet Expectations|
# |:--------|:------------------|
# |Area Plot|Mengimplementasikan Area Plot Menggunakan Matplotlib Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik|
# |Histogram|Mengimplementasikan Histogram Menggunakan Matplotlib Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik|
# |Bar Chart|Mengimplementasikan Bar Chart Menggunakan Matplotlib Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik|
# |Pie Chart|Mengimplementasikan Pie Chart Menggunakan Matplotlib Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik|
# |Box Plot|Mengimplementasikan Box plot Menggunakan Matplotlib Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik|
# |Scatter Plot|Mengimplementasikan Histogram Menggunakan Matplotlib Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik|
# |Word Clouds|Mengimplementasikan Word Clouds Menggunakan Wordclouds Library Dengan Data Yang Relevan Dan Sesuai Dengan Kegunaan Plot/Grafik|
# |Folium Maps|Mengimplementasikan London Maps Menggunakan Folium|
# |PreProcessing|Student Melakukan Preproses Dataset Sebelum Menerapkan Visualisasi.|
# |Apakah Kode Berjalan Tanpa Ada Eror?|Seluruh Kode Berfungsi Dan Dibuat Dengan Benar|
#
#
# **Readibility**
#
# |Criteria|Meet Expectations|
# |:--------|:------------------|
# |Tertata dengan baik|Semua Cell Di Notebook Terdokumentasi Dengan Baik Dengan Markdown Pada Tiap Cell Untuk Penjelasan Kode.|
#
#
# **Analysis**
#
# |Criteria|Meet Expectations|
# |:--------|:------------------|
# |Area Plot|Menarik Informasi/Kesimpulan Berdasarkan Area Plot Yang Telah Student Buat|
# |Histogram|Menarik Informasi/Kesimpulan Berdasarkan Histogram Yang Telah Student Buat|
# |Bar Chart|Menarik Informasi/Kesimpulan Berdasarkan Bar Chart Yang Telah Student Buat|
# |Pie Chart|Menarik Informasi/Kesimpulan Berdasarkan Pie Chart Yang Telah Student Buat|
# |Box Plot|Menarik Informasi/Kesimpulan Berdasarkan Box Plot Yang Telah Student Buat|
# |Scatter Plot|Menarik Informasi/Kesimpulan Berdasarkan Scatter Plot Yang Telah Student Buat|
# |Overall Analysis| Menarik Informasi/Kesimpulan Dari Keseluruhan Plot Yang Dapat Menjawab Hipotesis|
#
#
# - Sumber data https://www.kaggle.com/datasets/jboysen/london-crime.

# %% [markdown]
# ## A. Import Library
# Mengimport library-library apa saja yang dibutuhkan

# %%
import numpy as np                   #library Python yang fokus pada scientific computing.
import pandas as pd                  #untuk memproses data
import matplotlib.pyplot as plt      #untuk visualisasi data seperti plot grafik
import matplotlib as mpl             #untuk import statistics collected dari public Jupyter notebooks
import folium                        #untuk visualisasi peta
from wordcloud import WordCloud, STOPWORDS  #untuk visualisasi kata yang sering muncul

# %% [markdown]
# ## B. Data Understanding
# Data understanding adalah sebuah tahapan yang bertujuan untuk mendapatkan pemahaman awal mengenai data yang dibutuhkan untuk memecahkan permasalahan yang diberikan.
#
# ## C. Data Collection
# Data collection atau pengumpulan data adalah prosedur mengumpulkan, mengukur, dan menganalisis berbagai tipe informasi menggunakan teknik yang berstandar.

# %%
import pandas as pd
df = pd.read_csv("london_crime_by_lsoa.csv")
df
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %% [markdown]
# Detail tentang data ini :
# - lsoa_code: code for Lower Super Output Area in Greater London.
# - borough: Common name for London borough.
# - major_category: High level categorization of crime
# - minor_category: Low level categorization of crime within major category.
# - value: monthly reported count of categorical crime in given borough
# - year: Year of reported counts, 2008-2016
# - month: Month of reported counts, 1-12
#
# Sumber data : https://www.kaggle.com/datasets/jboysen/london-crime

# %% [markdown]
# ## D. Data Exploration
# Data exploration adalah pendekatan yang mirip dengan analisis data awal yang meliputi memeriksa jumlah data, tipe data, dan statistika.
#
# ### D.1. Melihat jumlah data yang ada

# %%
df
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %% [markdown]
# ### D.2. Melihat bentuk dari data (Baris, Kolom)

# %%
df.shape
# Out:
# (13490604, 7)

# %% [markdown]
# ### D.3. Melihat tipe data

# %%
df.info
# Out:
# <bound method DataFrame.info of           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %% [markdown]
# ### D.4. Melihat sebagian data
# - .head() untuk melihat data paling atas
# - .tail() untuk melihat data paling bawah

# %%
df.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
df.tail()
# Out:
#           lsoa_code     borough               major_category  \
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 13490599  Criminal Damage To Dwelling      0  2015      2
# 13490600            Personal Property      1  2015      6
# 13490601       Burglary in a Dwelling      0  2011      2
# 13490602            Business Property      0  2011      5
# 13490603                 Wounding/GBH      0  2015      6

# %% [markdown]
# ### D.5. Melihat deskripsi data

# %%
df.describe()
# Out:
#               value          year         month
# count  1.349060e+07  1.349060e+07  1.349060e+07
# mean   4.779444e-01  2.012000e+03  6.500000e+00
# std    1.771513e+00  2.581989e+00  3.452053e+00
# min    0.000000e+00  2.008000e+03  1.000000e+00
# 25%    0.000000e+00  2.010000e+03  3.750000e+00
# 50%    0.000000e+00  2.012000e+03  6.500000e+00
# 75%    1.000000e+00  2.014000e+03  9.250000e+00
# max    3.090000e+02  2.016000e+03  1.200000e+01

# %% [markdown]
# ## E. Data cleaning
# Data cleaning adalah proses menyiapkan data dengan cara menghapus atau memodifikasi data yang salah, tidak relevan, tidak akurat, duplikat, maupun yang tidak terformat.
#
# ### E.1. Mengecek apakah ada nilai NaN pada dataframe

# %%
df.isna().sum()
# Out:
# lsoa_code         0
# borough           0
# major_category    0
# minor_category    0
# value             0
# year              0
# month             0
# dtype: int64

# %% [markdown]
# ### E. 2. Mengecek apakah ada data duplicate

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Diperoleh informasi bahwa:
# - Data tersebut tidak memiliki nilai NaN
# - Data tersebut tidak memiliki nilai duplicate
#
# ---------------------------------

# %% [markdown]
# ## F. PreProcessing Data
# Data preprocessing adalah proses yang mengubah data mentah ke dalam bentuk yang lebih mudah dipahami.

# %%
df
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %% [markdown]
# ### F.1. Menghapus kolom yang tidak diperlukan
# Dapat dipilih kolom mana yang sekiranya tidak dibutuhkan dalam visualisasi data. Pada data ini, kolom lsoa_code tidak diperlukan, jadi saya akan menghapusnya.

# %%
df.drop(['lsoa_code'], axis=1, inplace=True)

# %%
df
# Out:
#              borough               major_category  \
# 0            Croydon                     Burglary
# 1          Greenwich  Violence Against the Person
# 2            Bromley  Violence Against the Person
# 3          Redbridge                     Burglary
# 4         Wandsworth                      Robbery
# ...              ...                          ...
# 13490599       Brent              Criminal Damage
# 13490600  Hillingdon                      Robbery
# 13490601      Sutton                     Burglary
# 13490602     Croydon                      Robbery
# 13490603      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# 2                      Other violence      0  2015      5
# 3         Burglary in Other Buildings      0  2016      3
# 4                   Personal Property      0  2008      6
# ...

# %% [markdown]
# Sekarang, kolom lsoa_code sudah menghilang.
#
# ### F.2. Mengubah nama kolom
# Mengubah nama kolom menjadi lebih mudah dipahami. Dalam data ini, saya mengubah nama kolom:
# - borough menjadi City
# - value menjadi Counted

# %%
df.rename(columns={'borough':'City', 'value':'Counted'}, inplace=True)

# %%
df
# Out:
#                 City               major_category  \
# 0            Croydon                     Burglary
# 1          Greenwich  Violence Against the Person
# 2            Bromley  Violence Against the Person
# 3          Redbridge                     Burglary
# 4         Wandsworth                      Robbery
# ...              ...                          ...
# 13490599       Brent              Criminal Damage
# 13490600  Hillingdon                      Robbery
# 13490601      Sutton                     Burglary
# 13490602     Croydon                      Robbery
# 13490603      Merton  Violence Against the Person
#
#                        minor_category  Counted  year  month
# 0         Burglary in Other Buildings        0  2016     11
# 1                      Other violence        0  2016     11
# 2                      Other violence        0  2015      5
# 3         Burglary in Other Buildings        0  2016      3
# ...

# %% [markdown]
# Sekarang kolom borough sudah berganti nama menjadi City, dan kolom value sudah berganti nama menjadi Counted.

# %% [markdown]
# ## G. Pengolahan data
#
# Rumusan masalah:
# 1. Bagaimana grafik pergerakan Top 5 major category dari tahun 2008 - 2016?
# 2. Kota mana saja yang mengalami top 5 major category namun dengan jumlah 5 terendah di tahun 2013?
# 3. Berapa persentase kejahatan yang paling banyak terjadi di kota Merton pada tahun 2010? Tampilkan juga visual kota Merton!
# 4. Bagaimana perbandingan banyak kejahatan 'Criminal Damage' di kota Wandsworth dan Greenwich pada tahun 2008 - 2016?
# 5. Berapakah total Top 5 major crime setiap tahunnya?
# 6. Bagaimana visualisasi kota-kota dengan tingkat kejahatan tertinggi menggunakan Word Cloud?
#
# Untuk menyelesaikan rumusan masalah menggunakan data tersebut, saya menggunakan Top 5 Major Category atau Kejahatan utama dengan jumlah 5 teratas.

# %% [markdown]
# ### 1. Bagaimana grafik pergerakan Top 5 major category dari tahun 2008 - 2016?
# ---------------------------------
#
# **Langkah 1 : Mendapatkan Top 5 major category**
#
# Dengan cara mengambil kolom yang diperlukan (major_category), menghitung jumlahnya, dan menampilkan 5 teratas. Sehingga diperoleh hasil Top 5 major category seperti sebagai berikut.

# %%
df['major_category'].value_counts().head(5)
# Out:
# Theft and Handling             3966300
# Violence Against the Person    3171744
# Criminal Damage                2069172
# Drugs                          1179468
# Burglary                       1043604
# Name: major_category, dtype: int64

# %% [markdown]
# **Langkah 2 : Mengelompokkan data pada kolom major_category dan year pada dataframe df**
#
# Dengan cara menggunakan condition pada dataframe df yang memiliki year > 2007 dan groupby untuk melakukan pengelompokan data. Kemudian, jumlahkan masing-masing major_categori dengan sum().

# %%
major = df[(df['year'] > 2007)].groupby(['major_category','year'])['Counted'].sum()
major
# Out:
# major_category               year
# Burglary                     2008     88092
#                              2009     90619
#                              2010     86826
#                              2011     93315
#                              2012     93392
#                                       ...
# Violence Against the Person  2012    150014
#                              2013    146181
#                              2014    185349
#                              2015    218740
#                              2016    232381
# Name: Counted, Length: 81, dtype: int64

# %% [markdown]
# **Langkah 3 : Mengelompokkan data berdasarkan Top 5 major_category**
#
# Dengan cara mendefinisikan variabel baru. Nanti akan diketahui urutan tahun dan banyaknya masing-masing kejahatan pada Top 5 major_category (Theft and Handling, Violence Against the Person, Criminal Damage, Drugs, Burglary) yang dilakukan pada tahun tersebut.

# %%
Tehand = major['Theft and Handling']
Tehand
# Out:
# year
# 2008    283692
# 2009    279492
# 2010    290924
# 2011    309292
# 2012    334054
# 2013    306372
# 2014    279880
# 2015    284022
# 2016    294133
# Name: Counted, dtype: int64

# %%
Violence = major['Violence Against the Person']
Violence
# Out:
# year
# 2008    159844
# 2009    160777
# 2010    157894
# 2011    146901
# 2012    150014
# 2013    146181
# 2014    185349
# 2015    218740
# 2016    232381
# Name: Counted, dtype: int64

# %%
Crimdam = major['Criminal Damage']
Crimdam
# Out:
# year
# 2008    91872
# 2009    85565
# 2010    77897
# 2011    70914
# 2012    62158
# 2013    56206
# 2014    59279
# 2015    62976
# 2016    64071
# Name: Counted, dtype: int64

# %%
Drugs = major['Drugs']
Drugs
# Out:
# year
# 2008    68804
# 2009    60549
# 2010    58674
# 2011    57550
# 2012    51776
# 2013    50278
# 2014    44435
# 2015    39785
# 2016    38914
# Name: Counted, dtype: int64

# %%
Bgry = major['Burglary']
Bgry
# Out:
# year
# 2008    88092
# 2009    90619
# 2010    86826
# 2011    93315
# 2012    93392
# 2013    87222
# 2014    76053
# 2015    70489
# 2016    68285
# Name: Counted, dtype: int64

# %% [markdown]
# **Langkah 4 : Mengonvert menjadi data frame baru**
#
# Dengan cara menggunakan function **.to_frame()**, kemudian rename nama kolom 'Counted' menjadi masing-masing kejahatan pada Top 5 major_category (Theft and Handling, Violence Against the Person, Criminal Damage, Drugs, Burglary).

# %%
dfTehand = Tehand.to_frame()
dfTehand.rename(columns={'Counted': 'Theft and Handling'}, inplace=True)
dfTehand.index.name=None
dfTehand
# Out:
#       Theft and Handling
# 2008              283692
# 2009              279492
# 2010              290924
# 2011              309292
# 2012              334054
# 2013              306372
# 2014              279880
# 2015              284022
# 2016              294133

# %%
dfViolence = Violence.to_frame()
dfViolence.rename(columns={'Counted': 'Violence Against the Person'}, inplace=True)
dfViolence.index.name=None
dfViolence
# Out:
#       Violence Against the Person
# 2008                       159844
# 2009                       160777
# 2010                       157894
# 2011                       146901
# 2012                       150014
# 2013                       146181
# 2014                       185349
# 2015                       218740
# 2016                       232381

# %%
dfCrimdam = Crimdam.to_frame()
dfCrimdam.rename(columns={'Counted': 'Criminal Damage'}, inplace=True)
dfCrimdam.index.name=None
dfCrimdam
# Out:
#       Criminal Damage
# 2008            91872
# 2009            85565
# 2010            77897
# 2011            70914
# 2012            62158
# 2013            56206
# 2014            59279
# 2015            62976
# 2016            64071

# %%
dfDrugs = Drugs.to_frame()
dfDrugs.rename(columns={'Counted': 'Drugs'}, inplace=True)
dfDrugs.index.name=None
dfDrugs
# Out:
#       Drugs
# 2008  68804
# 2009  60549
# 2010  58674
# 2011  57550
# 2012  51776
# 2013  50278
# 2014  44435
# 2015  39785
# 2016  38914

# %%
dfBgry = Bgry.to_frame()
dfBgry.rename(columns={'Counted': 'Burglary'}, inplace=True)
dfBgry.index.name=None
dfBgry
# Out:
#       Burglary
# 2008     88092
# 2009     90619
# 2010     86826
# 2011     93315
# 2012     93392
# 2013     87222
# 2014     76053
# 2015     70489
# 2016     68285

# %% [markdown]
# **Langkah 5: Menggabungkan masing-masing dataframe menjadi satu**
#
# Dengan cara membuat variabel baru dan menggunakan function **pd.concat([])**. Sehingga diperoleh urutan tahun, dan jumlah masing-masing kejahatan pada Top 5 major_category (Theft and Handling, Violence Against the Person, Criminal Damage, Drugs, Burglary).

# %%
df_top5 = pd.concat([dfTehand,dfViolence,dfCrimdam,dfDrugs,dfBgry], axis=1)
df_top5
# Out:
#       Theft and Handling  Violence Against the Person  Criminal Damage  Drugs  \
# 2008              283692                       159844            91872  68804
# 2009              279492                       160777            85565  60549
# 2010              290924                       157894            77897  58674
# 2011              309292                       146901            70914  57550
# 2012              334054                       150014            62158  51776
# 2013              306372                       146181            56206  50278
# 2014              279880                       185349            59279  44435
# 2015              284022                       218740            62976  39785
# 2016              294133                       232381            64071  38914
#
#       Burglary
# 2008     88092
# 2009     90619
# 2010     86826
# 2011     93315
# 2012     93392
# 2013     87222
# 2014     76053
# 2015     70489
# 2016     68285

# %% [markdown]
# **Langkah 6 : Membuat Line Plot Top 5 major_category**
#
# Dengan cara menggunakan function **.plot()** dan menambahkan ornamen lain seperti x label, y label, dan judul. Hasilnya berupa diagram garis sebagai berikut.

# %%
df_top5.plot() # memanggil plot line
plt.rcParams['figure.figsize'] = [12,10] #mengubah ukuran canvas plot line
plt.xlabel('Year') #menyeting label x
plt.ylabel('Number of Crimes') #menyeting label y
plt.title('Top 5 types and number of crimes in london in 2007-2016') #judul plot line
plt.show() #menampilkan

# %% [markdown]
# **Langkah 7 : Membuat Area Plot Top 5 major_category**
#
# Dengan menggunakan function **.plot(kind='area')** dan menambahkan  ornamen lain seperti x label, y label, dan judul. Hasilnya berupa diagram area sebagai berikut.

# %%
df_top5.index = df_top5.index.map(int)

df_top5.plot(kind='area',
            stacked=False,
            figsize=(15,10),
            )

plt.title("Top 5 major crime in London 2008 - 2016")
plt.ylabel('Number of Criminal')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Grafik pergerakan Top 5 major category dari tahun 2008 - 2016 :
# 1. Theft and Handling
#     - Merupakan kejahatan yang paling banyak terjadi sepanjang tahun 2008 - 2016 di London.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Theft and Handling mencapai 3.966.300 kasus.
#     - Berdasarkan grafik,diperoleh hasil bahwa kejahatan Theft and Handling turun ditahun 2008 - 2009, naik secara
#       signifikan ditahun 2009 - 2012, turun ditahun 2012-2014, dan naik ditahun 2014-2016.
#
#
# 2. Violence Against the Person
#     - Merupakan kejahatan kedua yang paling banyak terjadi sepanjang tahun 2008 - 2016 di London.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Violence Against the Person mencapai 3.171.744 kasus.
#     - Berdasarkan grafik,diperoleh hasil bahwa kejahatan Violence Against the Person turun melandai ditahun 2008 - 2011, turun naik ditahun 2011 - 2013, dan naik secara drastis ditahun 2013-2016.
#
#
# 3. Criminal Damage
#     - Merupakan kejahatan ketiga yang paling banyak terjadi sepanjang tahun 2008 - 2016 di London.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Criminal Damage mencapai 2.069.172 kasus.
#     - Berdasarkan grafik,diperoleh hasil bahwa kejahatan Criminal Damage turun melandai ditahun 2008 - 2013, dan naik melandai ditahun 2013-2016.
#
#
# 4. Drugs
#     - Merupakan kejahatan keempat yang paling banyak terjadi sepanjang tahun 2008 - 2016 di London.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Drugs mencapai 1.179.468 kasus.
#     - Berdasarkan grafik,diperoleh hasil bahwa kejahatan Drugs naik turun ditahun 2008 - 2010, naik turun ditahun 2010 - 2014, dan turun melandai ditahun 2014 - 2016.
#
#
# 5. Burglary
#     - Merupakan kejahatan kelima yang paling banyak terjadi sepanjang tahun 2008 - 2016 di London.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Burglary mencapai 1.043.604 kasus.
#     - Berdasarkan grafik,diperoleh hasil bahwa kejahatan Burglary turun melandai sepanjang tahun 2008 - 2016, grafik Burglary bisa dipilang paling mendekati konstan dibanding grafik kejahatan lainnya.

# %% [markdown]
# -------------------------------------------
# ## 2. Kota mana saja yang mengalami Top 5 major category namun dengan jumlah 5 terendah di tahun 2013?

# %% [markdown]
# **Langkah 1: Memanggil kembali df_top5**

# %%
df_top5
# Out:
#       Theft and Handling  Violence Against the Person  Criminal Damage  Drugs  \
# 2008              283692                       159844            91872  68804
# 2009              279492                       160777            85565  60549
# 2010              290924                       157894            77897  58674
# 2011              309292                       146901            70914  57550
# 2012              334054                       150014            62158  51776
# 2013              306372                       146181            56206  50278
# 2014              279880                       185349            59279  44435
# 2015              284022                       218740            62976  39785
# 2016              294133                       232381            64071  38914
#
#       Burglary
# 2008     88092
# 2009     90619
# 2010     86826
# 2011     93315
# 2012     93392
# 2013     87222
# 2014     76053
# 2015     70489
# 2016     68285

# %% [markdown]
# **Langkah 2: Mengelompokkan data pada dataframe df**
#
# Dengan cara menggunakan condition pada dataframe df yang memiliki year = 2007, major_category = Theft and Handling, dan groupby untuk melakukan pengelompokan data. Kemudian, jumlahkan kasus major_category = Theft and Handling dengan sum().

# %%
City_Tehand = (df[(df['year'] == 2013)&(df['major_category'] == 'Theft and Handling')].groupby('City')['Counted'].sum())
City_Tehand
# Out:
# City
# Barking and Dagenham       6140
# Barnet                     9958
# Bexley                     4293
# Brent                      7776
# Bromley                    7725
# Camden                    15767
# City of London               79
# Croydon                   10307
# Ealing                    10564
# Enfield                    8814
# Greenwich                  7319
# Hackney                   12180
# Hammersmith and Fulham     9048
# Haringey                   9305
# Harrow                     4057
# Havering                   6312
# Hillingdon                 8177
# Hounslow                   7911
# Islington                 12169
# Kensington and Chelsea    10742
# Kingston upon Thames       4161
# Lambeth                   13995
# Lewisham                   7319
# Merton                     4930
# Newham                    12271
# Redbridge                  8099
# Richmond upon Thames       4489
# Southwark                 13689
# Sutton                     4173
# ...

# %% [markdown]
# **Langkah 3: Mengonvert ke dataframe baru dan mengurutkan data**
#
# Dengan cara menggunakan function **.to_frame()**, kemudian urutkan dengan function **.sort_values**, dan gunakan function **.tail(5)** untuk mengetahui kejahatan top 5 major category namun dengan jumlah 5 terendah.

# %%
City_Tehand.to_frame()
df_sorted_City_Tehand = City_Tehand.sort_values(ascending=False).tail(5)
df_sorted_City_Tehand
# Out:
# City
# Bexley                  4293
# Sutton                  4173
# Kingston upon Thames    4161
# Harrow                  4057
# City of London            79
# Name: Counted, dtype: int64

# %% [markdown]
# **Langkah 4: Mengelompokkan data pada dataframe df**
#
# Dengan cara menggunakan condition pada dataframe df yang memiliki year = 2007, major_category = Violence Against the Person, dan groupby untuk melakukan pengelompokan data. Kemudian, jumlahkan kasus major_category = Violence Against the Person dengan sum().

# %%
City_Violence = (df[(df['year'] == 2013)&(df['major_category'] == 'Violence Against the Person')].groupby('City')['Counted'].sum())
City_Violence
# Out:
# City
# Barking and Dagenham      3889
# Barnet                    4292
# Bexley                    2714
# Brent                     5997
# Bromley                   4207
# Camden                    4551
# City of London              14
# Croydon                   6186
# Ealing                    6285
# Enfield                   4516
# Greenwich                 5078
# Hackney                   5745
# Hammersmith and Fulham    3961
# Haringey                  4433
# Harrow                    3008
# Havering                  3264
# Hillingdon                4955
# Hounslow                  5047
# Islington                 4894
# Kensington and Chelsea    2530
# Kingston upon Thames      2045
# Lambeth                   6861
# Lewisham                  5941
# Merton                    2464
# Newham                    6154
# Redbridge                 4238
# Richmond upon Thames      1910
# Southwark                 6254
# Sutton                    2375
# Tower Hamlets             6313
# ...

# %% [markdown]
# **Langkah 5: Mengonvert ke dataframe baru dan mengurutkan data**
#
# Dengan cara menggunakan function **.to_frame()**, kemudian urutkan dengan function **.sort_values**, dan gunakan function **.tail(5)** untuk mengetahui kejahatan top 5 major category namun dengan jumlah 5 terendah.

# %%
City_Violence.to_frame()
df_sorted_City_Violence = City_Violence.sort_values(ascending=False).tail(5)
df_sorted_City_Violence
# Out:
# City
# Merton                  2464
# Sutton                  2375
# Kingston upon Thames    2045
# Richmond upon Thames    1910
# City of London            14
# Name: Counted, dtype: int64

# %% [markdown]
# **Langkah 6: Mengelompokkan data pada dataframe df**
#
# Dengan cara menggunakan condition pada dataframe df yang memiliki year = 2007, major_category = Criminal Damage, dan groupby untuk melakukan pengelompokan data. Kemudian, jumlahkan kasus major_category = Criminal Damage dengan sum().

# %%
City_CrimDam = (df[(df['year'] == 2013)&(df['major_category'] == 'Criminal Damage')].groupby('City')['Counted'].sum())
City_CrimDam
# Out:
# City
# Barking and Dagenham      1619
# Barnet                    1855
# Bexley                    1432
# Brent                     1994
# Bromley                   1995
# Camden                    1576
# City of London               3
# Croydon                   2821
# Ealing                    2254
# Enfield                   1964
# Greenwich                 2013
# Hackney                   1659
# Hammersmith and Fulham    1196
# Haringey                  1862
# Harrow                    1134
# Havering                  1486
# Hillingdon                2149
# Hounslow                  1988
# Islington                 1592
# Kensington and Chelsea     824
# Kingston upon Thames       947
# Lambeth                   2415
# Lewisham                  2188
# Merton                    1205
# Newham                    2081
# Redbridge                 1488
# Richmond upon Thames      1147
# Southwark                 2370
# Sutton                    1219
# Tower Hamlets             2054
# ...

# %% [markdown]
# **Langkah 7: Mengonvert ke dataframe baru dan mengurutkan data**
#
# Dengan cara menggunakan function **.to_frame()**, kemudian urutkan dengan function **.sort_values**, dan gunakan function **.tail(5)** untuk mengetahui kejahatan top 5 major category namun dengan jumlah 5 terendah.

# %%
City_CrimDam.to_frame()
df_sorted_City_CrimDam = City_CrimDam.sort_values(ascending=False).tail(5)
df_sorted_City_CrimDam
# Out:
# City
# Richmond upon Thames      1147
# Harrow                    1134
# Kingston upon Thames       947
# Kensington and Chelsea     824
# City of London               3
# Name: Counted, dtype: int64

# %% [markdown]
# **Langkah 8: Mengelompokkan data pada dataframe df**
#
# Dengan cara menggunakan condition pada dataframe df yang memiliki year = 2007, major_category = Drugs, dan groupby untuk melakukan pengelompokan data. Kemudian, jumlahkan kasus major_category = Drugs dengan sum().

# %%
City_Drugs = (df[(df['year'] == 2013)&(df['major_category'] == 'Drugs')].groupby('City')['Counted'].sum())
City_Drugs
# Out:
# City
# Barking and Dagenham      1079
# Barnet                    1041
# Bexley                     837
# Brent                     3341
# Bromley                   1046
# Camden                    2172
# City of London               4
# Croydon                   2079
# Ealing                    1897
# Enfield                   1557
# Greenwich                 1311
# Hackney                   1883
# Hammersmith and Fulham    1958
# Haringey                  1196
# Harrow                     892
# Havering                  1006
# Hillingdon                1031
# Hounslow                  1493
# Islington                 1410
# Kensington and Chelsea    1098
# Kingston upon Thames       588
# Lambeth                   1894
# Lewisham                  1714
# Merton                     638
# Newham                    1622
# Redbridge                 1796
# Richmond upon Thames       628
# Southwark                 2657
# Sutton                     477
# Tower Hamlets             3019
# ...

# %% [markdown]
# **Langkah 9: Mengonvert ke dataframe baru dan mengurutkan data**
#
# Dengan cara menggunakan function **.to_frame()**, kemudian urutkan dengan function **.sort_values**, dan gunakan function **.tail(5)** untuk mengetahui kejahatan top 5 major category namun dengan jumlah 5 terendah.

# %%
City_Drugs.to_frame()
df_sorted_City_Drugs = City_Drugs.sort_values(ascending=False).tail(5)
df_sorted_City_Drugs
# Out:
# City
# Merton                  638
# Richmond upon Thames    628
# Kingston upon Thames    588
# Sutton                  477
# City of London            4
# Name: Counted, dtype: int64

# %% [markdown]
# **Langkah 10: Mengelompokkan data pada dataframe df**
#
# Dengan cara menggunakan condition pada dataframe df yang memiliki year = 2007, major_category = Burglary, dan groupby untuk melakukan pengelompokan data. Kemudian, jumlahkan kasus major_category = Burglary dengan sum().

# %%
City_Brgy = (df[(df['year'] == 2013)&(df['major_category'] == 'Burglary')].groupby('City')['Counted'].sum())
City_Brgy
# Out:
# City
# Barking and Dagenham      2222
# Barnet                    4262
# Bexley                    1784
# Brent                     3084
# Bromley                   3121
# Camden                    3085
# City of London               3
# Croydon                   3958
# Ealing                    3584
# Enfield                   3449
# Greenwich                 2369
# Hackney                   2784
# Hammersmith and Fulham    1514
# Haringey                  2731
# Harrow                    2097
# Havering                  2480
# Hillingdon                2853
# Hounslow                  2473
# Islington                 2394
# Kensington and Chelsea    1754
# Kingston upon Thames      1190
# Lambeth                   3876
# Lewisham                  3297
# Merton                    1763
# Newham                    2904
# Redbridge                 2993
# Richmond upon Thames      1927
# Southwark                 3458
# Sutton                    1427
# Tower Hamlets             2695
# ...

# %% [markdown]
# **Langkah 11: Mengonvert ke dataframe baru dan mengurutkan data**
#
# Dengan cara menggunakan function **.to_frame()**, kemudian urutkan dengan function **.sort_values**, dan gunakan function **.tail(5)** untuk mengetahui kejahatan top 5 major category namun dengan jumlah 5 terendah.

# %%
City_Brgy.to_frame()
df_sorted_City_Brgy = City_Brgy.sort_values(ascending=False).tail(5)
df_sorted_City_Brgy
# Out:
# City
# Kensington and Chelsea    1754
# Hammersmith and Fulham    1514
# Sutton                    1427
# Kingston upon Thames      1190
# City of London               3
# Name: Counted, dtype: int64

# %% [markdown]
# **Langkah 12: Membuat bar chart kota-kota yang mengalami top 5 major category namun dengan jumlah 5 terendah di tahun 2013**
#
# - Bar chart kejahatan Theft and Handling 5 terendah di tahun 2013
#
#     Dengan cara menggunakan function **.plot(kind='bar') -> untuk vertikal** kemudian tambahkan ornamen lainnya seperti size, judul, x label dan y label.

# %%
df_sorted_City_Tehand.plot(kind='bar',color='pink', figsize=(7,4))
plt.title("Kejahatan Theft and Handling 5 terendah di tahun 2013")
plt.xlabel("City")
plt.ylabel("Number of Counted") 
plt.show()

# %% [markdown]
# ----------------------------------
# - Bar chart kejahatan Violence Against the Person 5 terendah di tahun 2013
#
#     Dengan cara menggunakan function **.plot(kind='barh') -> untuk horizontal** kemudian tambahkan ornamen lainnya seperti size, judul, x label dan y label.

# %%
df_sorted_City_Violence.plot(kind='barh', color='pink', figsize=(7,4))
plt.title("Kejahatan Violence Against the Person 5 terendah di tahun 2013")
plt.xlabel("Number of Counted")
plt.ylabel("City") 
plt.show()

# %% [markdown]
# -----------------------------------------
# - Bar chart kejahatan Criminal Damage 5 terendah di tahun 2013
#
#     Dengan cara menggunakan function **.plot(kind='bar') -> untuk vertikal** kemudian tambahkan ornamen lainnya seperti size, judul, x label dan y label.

# %%
df_sorted_City_CrimDam.plot(kind='bar',color='pink', figsize=(7,4))
plt.title("Kejahatan Criminal Damage 5 terendah di tahun 2013")
plt.xlabel("City")
plt.ylabel("Number of Counted") 
plt.show()

# %% [markdown]
# ------------------------------
# - Bar chart kejahatan Drugs 5 terendah di tahun 2013
#
#     Dengan cara menggunakan function **.plot(kind='barh') -> untuk horizontal** kemudian tambahkan ornamen lainnya seperti size, judul, x label dan y label.

# %%
df_sorted_City_Drugs.plot(kind='barh',color='pink', figsize=(7,4))
plt.title("Kejahatan Drugs 5 terendah di tahun 2013")
plt.xlabel("Number of Counted")
plt.ylabel("City") 
plt.show()

# %% [markdown]
# -------------------
# - Bar chart kejahatan Burglary 5 terendah di tahun 2013
#
#     Dengan cara menggunakan function **.plot(kind='bar') -> untuk vertikal** kemudian tambahkan ornamen lainnya seperti size, judul, x label dan y label.

# %%
df_sorted_City_Brgy.plot(kind='bar', color='pink', figsize=(7,4))
plt.title("Kejahatan Burglary 5 terendah di tahun 2013")
plt.xlabel("City")
plt.ylabel("Number of Counted") 
plt.show()

# %% [markdown]
# ----------------------------
# **Kesimpulan**
#
# Kota-kota yang mengalami Top 5 major category namun dengan jumlah 5 terendah di tahun 2013:
# 1. Theft and Handling
#     - Rincian kota-kota dengan kasus Theft and Handling, 5 terendah diantaranya adalah sebagai berikut.
#
#     |City|Counted|
#     |:-------|:------|
#     |Bexley|4293|
#     |Sutton|4173|
#     |Kingston upon Thames|4161|
#     |Harrow|4057|
#     |City of London|79|
#
# 2. Violence Against the Person
#      - Rincian kota-kota dengan kasus Violence Against the Person, 5 terendah diantaranya adalah sebagai berikut.
# |City|Counted|
# |:-------|:------|
# |Merton|2464|
# |Sutton|2375|
# |Kingston upon Thames|2045|
# |Richmond upon Thames|1910|
# |City of London|14|
#
# 3. Criminal Damage
#      - Rincian kota-kota dengan kasus Criminal Damage, 5 terendah diantaranya adalah sebagai berikut.
# |City|Counted|
# |:-------|:------|
# |Richmond upon Thames|1147|
# |Harrow|1134|
# |Kingston upon Thames|947|
# |Kensington and Chelsea|824|
# |City of London|3|
#
#
# 4. Drugs
#      - Rincian kota-kota dengan kasus Drugs, 5 terendah diantaranya adalah sebagai berikut.
# |City|Counted|
# |:-------|:------|
# |Merton|638|
# |Richmond upon Thames|628|
# |Kingston upon Thames|588|
# |Sutton|477|
# |City of London|4|
#
# 5. Burglary
#      - Rincian kota-kota dengan kasus Burglary, 5 terendah diantaranya adalah sebagai berikut.
# |City|Counted|
# |:-------|:------|
# |Kensington and Chelsea  |  1754|
# |Hammersmith and Fulham   | 1514|
# |Sutton                   | 1427|
# |Kingston upon Thames      |1190|
# |City of London              | 3|

# %% [markdown]
# ---------------------------------
# ## 3. Apa saja kejahatan yang paling banyak terjadi di kota Merton pada tahun 2010? Tampilkan juga visual kota Merton!

# %% [markdown]
# **Langkah 1: Panggil kembali df_top5**

# %%
df_top5
# Out:
#       Theft and Handling  Violence Against the Person  Criminal Damage  Drugs  \
# 2008              283692                       159844            91872  68804
# 2009              279492                       160777            85565  60549
# 2010              290924                       157894            77897  58674
# 2011              309292                       146901            70914  57550
# 2012              334054                       150014            62158  51776
# 2013              306372                       146181            56206  50278
# 2014              279880                       185349            59279  44435
# 2015              284022                       218740            62976  39785
# 2016              294133                       232381            64071  38914
#
#       Burglary
# 2008     88092
# 2009     90619
# 2010     86826
# 2011     93315
# 2012     93392
# 2013     87222
# 2014     76053
# 2015     70489
# 2016     68285

# %% [markdown]
# **Langkah 2: Mengelompokkan data pada dataframe df**
#
# Dengan cara menggunakan condition pada dataframe df yang memiliki year = 2010, City = Merton, dan groupby major_category untuk melakukan pengelompokan data. Kemudian, jumlahkan masing-masing major_category dengan sum().

# %%
Merton = (df[(df['year'] == 2010) & (df['City'] == 'Merton')].groupby('major_category')['Counted'].sum())
Merton
# Out:
# major_category
# Burglary                       2069
# Criminal Damage                1808
# Drugs                           921
# Fraud or Forgery                  0
# Other Notifiable Offences       128
# Robbery                         542
# Sexual Offences                   0
# Theft and Handling             5228
# Violence Against the Person    2899
# Name: Counted, dtype: int64

# %% [markdown]
# **Langkah 3: Mengonvert ke dataframe baru dan mengurutkan data**
#
# Dengan cara menggunakan function **.to_frame()** untuk mengonvert ke dataframe baru, kemudian urutkan dengan function **.sort_values**, dan gunakan function **.head(5)** untuk mengetahui kejahatan paling sering terjadi di kota Merton.

# %%
Merton.to_frame()
df_sorted_Merton = Merton.sort_values(ascending=False).head(5)
df_sorted_Merton
# Out:
# major_category
# Theft and Handling             5228
# Violence Against the Person    2899
# Burglary                       2069
# Criminal Damage                1808
# Drugs                           921
# Name: Counted, dtype: int64

# %% [markdown]
# **Langkah 4: Melihat index**
#
# Dengan menggunakan function **.index**, dapat digunakan untuk labels visualisasi data nanti.

# %%
df_sorted_Merton.index
# Out:
# Index(['Theft and Handling', 'Violence Against the Person', 'Burglary',
#        'Criminal Damage', 'Drugs'],
#       dtype='object', name='major_category')

# %% [markdown]
# **Langkah 5: Melihat values**
#
# Dengan menggunakan function **.values**, berisi jumlah kejahatan yang terjadi di kota Merton.

# %%
df_sorted_Merton.values
# Out:
# array([5228, 2899, 2069, 1808,  921], dtype=int64)

# %% [markdown]
# **Langkah 6: Membuat Pie Chart**
#
# Dengan menggunakan function **.plot(kind='pie')** dan menambahkan  ornamen lain seperti x label, y label, dan judul. Hasilnya berupa diagram pie sebagai berikut.

# %%
#pilih warna
colors_list = ['gold','lightskyblue','lightgreen','pink','purple']

#pilih ukuran lingkaran
explode_list = [0.015, 0.05, 0.05, 0.05, 0.05]

#Tambahkan details
df_sorted_Merton.plot(kind='pie',
        figsize=(11,5),
        autopct='%1.1f%%',
        startangle=45,
        shadow=True,
        labels=None,
        pctdistance=1.2,
        colors=colors_list,
        explode=explode_list)

#untuk memberikan informasi daerah berwarna
plt.legend(labels=df_sorted_Merton.index,loc='upper left')
plt.axis('equal')

#menambahkan judul
plt.title('Kejahatan yang paling banyak terjadi di kota Merton pada tahun 2010',y=1.12)

#menampilkan
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Kejahatan (major_category) yang paling banyak terjadi di kota Merton pada tahun 2010, diantaranya adalah:
# 1. Theft and Handling
#     - Merupakan kejahatan yang paling banyak terjadi pada tahun 2010 di kota Merton.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Theft and Handling mencapai 5.228 kasus.
#     - Berdasarkan pie chart, diperoleh hasil bahwa kejahatan Theft and Handling sebesar 40,4%.
#
#
# 2. Violence Against the Person
#     - Merupakan kejahatan kedua yang paling banyak terjadi pada tahun 2010 di kota Merton.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Theft and Handling mencapai 2.899 kasus.
#     - Berdasarkan pie chart, diperoleh hasil bahwa kejahatan Theft and Handling sebesar 22,4%.
#
#
# 3. Burglary
#     - Merupakan kejahatan ketiga yang paling banyak terjadi pada tahun 2010 di kota Merton.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Theft and Handling mencapai 2.069 kasus.
#     - Berdasarkan pie chart, diperoleh hasil bahwa kejahatan Theft and Handling sebesar 16,0%.
#
#
# 4. Criminal Damage
#     - Merupakan kejahatan keempat yang paling banyak terjadi pada tahun 2010 di kota Merton.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Theft and Handling mencapai 1.808 kasus.
#     - Berdasarkan pie chart, diperoleh hasil bahwa kejahatan Theft and Handling sebesar 14,0%.
#
#
# 5. Drugs
#     - Merupakan kejahatan kelima yang paling banyak terjadi pada tahun 2010 di kota Merton.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Theft and Handling mencapai 921 kasus.
#     - Berdasarkan pie chart, diperoleh hasil bahwa kejahatan Theft and Handling sebesar 7,1%.

# %% [markdown]
# **Langkah 7: Menampilkan visual kota Merton**
#
# Dengan menggunkan **folium.Map()**

# %%
# define the world map centered around Merton with a low zoom level
world_map = folium.Map(location=[51.41665922623774, -0.18671127487886308], zoom_start=15)

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# **Kesimpulan**
#
# Hasilnya berupa maps kota Merton, London. Maps tersebut dapat di zoom in dan zoom out sesuai kebutuhan.

# %% [markdown]
# -----------------------------------
# ## 4. Bagaimana perbandingan banyak kejahatan Criminal Damage di kota Wandsworth dan Greenwich pada tahun 2008-2016?
#
# **Langkah 1: Memanggil kembali df_top5**

# %%
df_top5
# Out:
#       Theft and Handling  Violence Against the Person  Criminal Damage  Drugs  \
# 2008              283692                       159844            91872  68804
# 2009              279492                       160777            85565  60549
# 2010              290924                       157894            77897  58674
# 2011              309292                       146901            70914  57550
# 2012              334054                       150014            62158  51776
# 2013              306372                       146181            56206  50278
# 2014              279880                       185349            59279  44435
# 2015              284022                       218740            62976  39785
# 2016              294133                       232381            64071  38914
#
#       Burglary
# 2008     88092
# 2009     90619
# 2010     86826
# 2011     93315
# 2012     93392
# 2013     87222
# 2014     76053
# 2015     70489
# 2016     68285

# %% [markdown]
# **Langkah 2: Mengelompokkan data pada dataframe df (Kota Wandsworth)**
#
# Dengan cara menggunakan condition pada dataframe df yang memiliki major_category = Criminal Damage, City = Wandsworth, dan groupby (year) untuk melakukan pengelompokan data. Kemudian, jumlahkan kasus Criminal Damage dengan sum().

# %%
W = (df[(df['major_category'] == 'Criminal Damage') & (df['City'] == 'Wandsworth')].groupby('year')['Counted'].sum())
W
# Out:
# year
# 2008    2857
# 2009    2721
# 2010    2580
# 2011    2137
# 2012    2019
# 2013    1801
# 2014    1751
# 2015    1928
# 2016    1836
# Name: Counted, dtype: int64

# %% [markdown]
# **Langkah 3: Mengelompokkan data pada dataframe df (Kota Greenwhich)**
#
# Dengan cara menggunakan condition pada dataframe df yang memiliki major_category = Criminal Damage, City = Greenwich, dan groupby (year) untuk melakukan pengelompokan data. Kemudian, jumlahkan kasus Criminal Damage dengan sum().

# %%
G = (df[(df['major_category'] == 'Criminal Damage') & (df['City'] == 'Greenwich')].groupby('year')['Counted'].sum())
G
# Out:
# year
# 2008    3353
# 2009    3190
# 2010    2760
# 2011    2490
# 2012    2216
# 2013    2013
# 2014    1976
# 2015    2281
# 2016    2476
# Name: Counted, dtype: int64

# %% [markdown]
# **Langkah 4 : Mengonvert menjadi data frame baru**
#
# Dengan cara menggunakan function **.to_frame()**, kemudian rename nama kolom 'Counted' menjadi 'Criminal Damage in Wandsworth'.

# %%
dfW = W.to_frame()
dfW.rename(columns={'Counted': 'Criminal Damage in Wandsworth'}, inplace=True)
dfW.index.name=None
dfW
# Out:
#       Criminal Damage in Wandsworth
# 2008                           2857
# 2009                           2721
# 2010                           2580
# 2011                           2137
# 2012                           2019
# 2013                           1801
# 2014                           1751
# 2015                           1928
# 2016                           1836

# %% [markdown]
# **Langkah 4 : Mengonvert menjadi data frame baru**
#
# Dengan cara menggunakan function **.to_frame()**, kemudian rename nama kolom 'Counted' menjadi 'Criminal Damage in Greenwich'.

# %%
dfG = G.to_frame()
dfG.rename(columns={'Counted': 'Criminal Damage in Greenwich'}, inplace=True)
dfG.index.name=None
dfG
# Out:
#       Criminal Damage in Greenwich
# 2008                          3353
# 2009                          3190
# 2010                          2760
# 2011                          2490
# 2012                          2216
# 2013                          2013
# 2014                          1976
# 2015                          2281
# 2016                          2476

# %% [markdown]
# **Langkah 5: Menggabungkan masing-masing dataframe menjadi satu**
#
# Dengan cara membuat variabel baru dan menggunakan function **pd.concat([])**. Sehingga diperoleh urutan tahun, dan jumlah kasus Criminal Damage di Wandsorth dan Greenwich.

# %%
df_WG = pd.concat([dfW,dfG], axis=1)
df_WG
# Out:
#       Criminal Damage in Wandsworth  Criminal Damage in Greenwich
# 2008                           2857                          3353
# 2009                           2721                          3190
# 2010                           2580                          2760
# 2011                           2137                          2490
# 2012                           2019                          2216
# 2013                           1801                          2013
# 2014                           1751                          1976
# 2015                           1928                          2281
# 2016                           1836                          2476

# %% [markdown]
# **Langkah 6: Melihat deskripsi data**

# %%
df_WG.describe()
# Out:
#        Criminal Damage in Wandsworth  Criminal Damage in Greenwich
# count                       9.000000                      9.000000
# mean                     2181.111111                   2528.333333
# std                       425.483679                    487.996158
# min                      1751.000000                   1976.000000
# 25%                      1836.000000                   2216.000000
# 50%                      2019.000000                   2476.000000
# 75%                      2580.000000                   2760.000000
# max                      2857.000000                   3353.000000

# %% [markdown]
# **Langkah 7: Membuat Box Plot (Vertikal)**
#
# Dengan cara menggunakan function **.plot(kind=box)**, kemudian tambahkan ornamen lainnya seperti ukuran plot, judul, x label, dan y label.

# %%
df_WG.plot(kind='box', figsize=(8, 6))

plt.title('Box plot of Criminal Damage in Wandswort and Greenwich from 2008 - 2016')
plt.ylabel('Number of Counted')

plt.show()

# %% [markdown]
# **Langkah 8: Membuat Box Plot (Horizontal)**
#
# Dengan cara menggunakan function **.plot(kind=box, vert=False)**, kemudian tambahkan ornamen lainnya seperti ukuran plot, judul, x label, dan y label.

# %%
df_WG.plot(kind='box', figsize=(10, 7), color='blue', vert=False)

plt.title('Box plot of Criminal Damage in Wandswort and Greenwich from 2008 - 2016')
plt.xlabel('Number of Counted')

plt.show()

# %% [markdown]
# **Langkah 9: Membuat Histogram vertikal**
#
# Dengan cara menggunakan function **.plot(kind=hist)**, kemudian tambahkan ornamen lainnya seperti ukuran plot, judul, x label, dan y label.

# %%
df_WG.plot(kind='hist', figsize=(10, 6))

plt.title('Histogram of Criminal Damage in Wandswort and Greenwich from 2008 - 2016')
plt.ylabel('Number of Years')
plt.xlabel('Number of Counted')

plt.show()

# %% [markdown]
# **Langkah 10: Membuat Histogram horizontal**
#
# Dengan cara menggunakan function **.plot(kind=hist,orientation="horizontal")**, kemudian tambahkan ornamen lainnya seperti ukuran plot, judul, x label, dan y label.

# %%
df_WG.plot(kind='hist', figsize=(10, 6), orientation="horizontal")

plt.title('Histogram of Criminal Damage in Wandswort and Greenwich from 2008 - 2016')
plt.ylabel('Number of Counted')
plt.xlabel('Number of Years')

plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Perbandingan banyaknya kejahatan Criminal Damage di kota Wandsworth dan Greenwich pada tahun 2008-2016:
# 1. Criminal Damage in Wandsworth
#     - Berdasarkan Box plot (vertikan dan horizontal), diketahui bahwa jumlah kejahatan Criminal Damage di kota Wandsworth lebih sedikit dibanding jumlah kejahatan Criminal Damage di kota Greenwich sepanjang tahun 2008-2016. Hal ini dapat diketahui sesuai dengan posisi box plot di kota Wandswort yang lebih rendah dibanding box plot di kota Greenwich. Garis hijau menandakan rata-rata dari criminal damage in Wandsworth, yaitu sebanyak 2.181 kasus.
#     - Berdasarkan Histogram (vertikal dan horizontal), diketahui bahwa **Number of years** merupakan jumlah tahunnya, dan **Number of counted** merupakan jumlah kejahatan Criminal Damage yang terjadi, sehingga:
# |Jumlah Tahun|Jumlah kejahatan Criminal Damage di Wandsworth|
#     |:-------|:------|
#     |3|1.700 - 1.900 kasus|
#     |1|2.500 - 2.700 kasus|
#     |2|2.700 - 2.900 kasus|
#     - Dengan total kasus Criminal Damage terbanyak sebesar 2.857 kasus, dan terendah sebanyak 1.836 kasus.
#
#
# 2. Criminal Damage in Greenwich
#     - Berdasarkan Box plot (vertikan dan horizontal), diketahui bahwa jumlah kejahatan Criminal Damage di kota Greenwich lebih banyak dibanding jumlah kejahatan Criminal Damage di kota Wandsworth sepanjang tahun 2008-2016. Hal ini dapat diketahui sesuai dengan posisi box plot di kota Greenwich yang lebih tinggi dibanding box plot di kota Wandsworth. Garis hijau menandakan rata-rata dari criminal damage in Greenwich, yaitu sebanyak 2.528 kasus.
#     - Berdasarkan Histogram (vertikan dan horizontal), diketahui bahwa **Number of years** merupakan jumlah tahunnya, dan **Number of counted** merupakan jumlah kejahatan Criminal Damage yang terjadi, sehingga:
# |Jumlah Tahun|Jumlah kejahatan Criminal Damage di Greenwich|
#     |:-------|:------|
#     |2|1.900 - 2.100 kasus|
#     |1|2.100 - 2.400 kasus|
#     |2|2.400 - 2.500 kasus|
#     |1|2.700 - 2.900 kasus|
#     |1|3.100 - 3.300 kasus|
#     - Dengan total kasus Criminal Damage terbanyak sebesar 3.353 kasus, dan terendah sebanyak 2.476 kasus.

# %% [markdown]
# --------------------------
# ## 5. Berapakah total Top 5 major crime setiap tahunnya?

# %% [markdown]
# **Langkah 1: Memanggil df_top5 lagi**

# %%
df_top5
# Out:
#       Theft and Handling  Violence Against the Person  Criminal Damage  Drugs  \
# 2008              283692                       159844            91872  68804
# 2009              279492                       160777            85565  60549
# 2010              290924                       157894            77897  58674
# 2011              309292                       146901            70914  57550
# 2012              334054                       150014            62158  51776
# 2013              306372                       146181            56206  50278
# 2014              279880                       185349            59279  44435
# 2015              284022                       218740            62976  39785
# 2016              294133                       232381            64071  38914
#
#       Burglary
# 2008     88092
# 2009     90619
# 2010     86826
# 2011     93315
# 2012     93392
# 2013     87222
# 2014     76053
# 2015     70489
# 2016     68285

# %% [markdown]
# **Langkah 2: Menambahkan kolom baru (Total)**
#
# Karena ini kolom total, maka saya akan menjumlahkan setiap baris per tahunnya. Dengan cara menggunakan function **.sum(axis=1,numeric_only=True)**. Diperoleh hasil sebagai berikut.

# %%
df_top5['Total'] = df_top5.sum(axis=1,numeric_only=True) # horizontal / columns  , axis =0 vertical / rows 
df_top5
# Out:
#       Theft and Handling  Violence Against the Person  Criminal Damage  Drugs  \
# 2008              283692                       159844            91872  68804
# 2009              279492                       160777            85565  60549
# 2010              290924                       157894            77897  58674
# 2011              309292                       146901            70914  57550
# 2012              334054                       150014            62158  51776
# 2013              306372                       146181            56206  50278
# 2014              279880                       185349            59279  44435
# 2015              284022                       218740            62976  39785
# 2016              294133                       232381            64071  38914
#
#       Burglary   Total
# 2008     88092  692304
# 2009     90619  677002
# 2010     86826  672215
# 2011     93315  677972
# 2012     93392  691394
# 2013     87222  646259
# ...

# %% [markdown]
# **Langkah 3: Menambahkan kolom baru (Year)**
#
# Kolom Year dibuat untuk dapat membangun plot. Dengan cara mendefinisikan Year menjadi masing-masing tahun 2008 - 2016. Nantinya akan dipilih 2 kolom, yaitu Year dan Total untuk membuat visualisasinya. Diperoleh hasil sebagai berikut.

# %%
df_top5['Year'] = [2008,2009,2010,2011,2012,2013,2014,2015,2016] # horizontal / columns  , axis =0 vertical / rows 
df_top5
# Out:
#       Theft and Handling  Violence Against the Person  Criminal Damage  Drugs  \
# 2008              283692                       159844            91872  68804
# 2009              279492                       160777            85565  60549
# 2010              290924                       157894            77897  58674
# 2011              309292                       146901            70914  57550
# 2012              334054                       150014            62158  51776
# 2013              306372                       146181            56206  50278
# 2014              279880                       185349            59279  44435
# 2015              284022                       218740            62976  39785
# 2016              294133                       232381            64071  38914
#
#       Burglary   Total  Year
# 2008     88092  692304  2008
# 2009     90619  677002  2009
# 2010     86826  672215  2010
# 2011     93315  677972  2011
# 2012     93392  691394  2012
# ...

# %% [markdown]
# **Langkah 4: Memilih sebagian kolom**
#
# Pilih 2 kolom, yaitu Year dan Total untuk membuat visualisasi atau plotnya. Dengan cara menggunakan function **.loc[[nama_baris],[nama_kolom]]**. Diperoleh hasil sebagai berikut.

# %%
Tot = df_top5.loc[[2008,2009,2010,2011,2012,2013,2014,2015,2016],['Total','Year']]
Tot
# Out:
#        Total  Year
# 2008  692304  2008
# 2009  677002  2009
# 2010  672215  2010
# 2011  677972  2011
# 2012  691394  2012
# 2013  646259  2013
# 2014  644996  2014
# 2015  676012  2015
# 2016  697784  2016

# %% [markdown]
# **Langkah 5: Membuat plot Scatter**
#
# Dengan cara menggunakan function **.plot(kind='scatter', x='kolom1', y='kolom2'**, kemudian menambahkan ornamen lainnya seperti ukuran, warna, judul, x label, dan y label. Hasilnya sebagai berikut.

# %%
Tot.plot(kind='scatter', x='Year', y='Total', figsize=(7, 4), color='coral')
plt.title('Total Top 5 major crime from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Counted')
plt.show()

# %% [markdown]
# **Langkah 6: Membuat plot gabungan**
#
# Yaitu menggabungkan diargram garis dan diagram titik. Diperoleh hasil sebagai berikut.

# %%
#  Mendefinisikan component figure dan axes
fix = plt.figure()
ax  = plt.axes()

#  Mendefinisikan fungsi grid
ax.grid()

# Mendefinisikan nilai pada sumbu x dan sumbu y
xlabel = [2008,2009,2010,2011,2012,2013,2014,2015,2016]
ylabel = [692304,677002,672215,677972,691394,646259,644996,676012,697784]

# Mendefisikan fungsi untuk menampilkan visualisasi 
ax.plot(xlabel, ylabel, marker='D')
plt.rcParams['figure.figsize'] = [10,5]

# Menambahkan nama sumbu x, y, dan tittle
plt.xlabel('Year')
plt.ylabel('Number of Counted')
plt.title('Total Top 5 major crime from 1980 - 2013')

# Menampilkan plot
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Total Top 5 major category setiap tahunnya adalah sebagai berikut:
#
# |Year|Counted|Rank (Tertinggi)|
# |:-------|:------|:------|
# |2008| 692.304 | 2 |
#     |2009| 677.002 | 5 |
#     |2010| 672.215 | 7 |
#     |2011| 677.972 | 4 |
#     |2012| 691.394 | 3 |
#     |2013| 646.259 | 8 |
#     |2014| 644.996 | 9 |
#     |2015| 676.012 | 6 |
#     |2016| 697.784 | 1 |

# %% [markdown]
# --------------------
# ## 6. Bagaimana visualisasi kota-kota dengan tingkat kejahatan tertinggi dengan Word clouds?

# %% [markdown]
# **Langkah 1: Membuat wordcloud**
#
# Dengan langkah-langkah sebagai berikut.

# %%
# Membuat sample dataset
df_frac = df.sample(frac=0.1)

# Membuat WordCloud object
WC = WordCloud(width = 800, height = 800, background_color = 'white')

# Membuat string dari kolom City
text = " ".join(cat for cat in df_frac['City']) 

# Generate the word cloud
WC.generate(text)

# Plot the word cloud
plt.figure(figsize=(8,8), facecolor = None)
plt.imshow(WC)
plt.axis("off")
plt.tight_layout(pad = 0)

# Tampilkan plot
plt.show()

# %% [markdown]
# **Langkah 2: Membuat word cloud dengan gambar**
#
# Langkah-langkahnya sebagai berikut.

# %%
from PIL import Image # Convert gambar ke arrays

# %%
# Mendefinisikan gambar 
London_mask = np.array(Image.open('London_mask.png'))
    
print('Gambar sudah siap!')
# Out:
# Gambar sudah siap!

# %%
# Gambar sudah berubah menjadi array
London_mask
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
# Untuk mengetahui bentuk array (baris, kolom)
London_mask.shape
# Out:
# (400, 667)

# %%
# instantiate a word cloud object
London_wc = WordCloud(background_color='white', max_words=1000, mask=London_mask)

# generate the word cloud
London_wc.generate(text)

# display the word cloud
fig = plt.figure()
fig.set_figwidth(30) # set width
fig.set_figheight(30) # set height

plt.imshow(London_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# **Kesimpulan**
#
# Dapat dilihat bahwa kota dengan font paling besar (menandakan kota tersebut memiliki tingkat kejahatan yang tinggi), diantaranya adalah sebagai berikut.
# 1. Thames
# 2. Tower Hamlets
# 3. Waltham Forest
# 4. Richmond upon
# 5. Kingston upon

# %% [markdown]
# ----------------------------------------
# ### H. **Kesimpulan Keseluruhan**
#
# ----------------------------------------------------
# **1. Bagaimana grafik pergerakan Top 5 major category dari tahun 2008 - 2016?**
#
#     Grafik pergerakan Top 5 major category dari tahun 2008 - 2016 :
#
#     1) Theft and Handling
#     - Merupakan kejahatan yang paling banyak terjadi sepanjang tahun 2008 - 2016 di London.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Theft and Handling mencapai 3.966.300 kasus.
#     - Berdasarkan grafik,diperoleh hasil bahwa kejahatan Theft and Handling turun ditahun 2008 - 2009, naik secara
#       signifikan ditahun 2009 - 2012, turun ditahun 2012-2014, dan naik ditahun 2014-2016.
#
#     2) Violence Against the Person
#     - Merupakan kejahatan kedua yang paling banyak terjadi sepanjang tahun 2008 - 2016 di London.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Violence Against the Person mencapai 3.171.744 kasus.
#     - Berdasarkan grafik,diperoleh hasil bahwa kejahatan Violence Against the Person turun melandai ditahun 2008 - 2011,
#       turun naik ditahun 2011 - 2013, dan naik secara drastis ditahun 2013-2016.
#
#     3) Criminal Damage
#     - Merupakan kejahatan ketiga yang paling banyak terjadi sepanjang tahun 2008 - 2016 di London.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Criminal Damage mencapai 2.069.172 kasus.
#     - Berdasarkan grafik,diperoleh hasil bahwa kejahatan Criminal Damage turun melandai ditahun 2008 - 2013, dan naik
#       melandai ditahun 2013-2016.
#
#     4) Drugs
#     - Merupakan kejahatan keempat yang paling banyak terjadi sepanjang tahun 2008 - 2016 di London.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Drugs mencapai 1.179.468 kasus.
#     - Berdasarkan grafik,diperoleh hasil bahwa kejahatan Drugs naik turun ditahun 2008 - 2010, naik turun ditahun 2010 -
#       2014, dan turun melandai ditahun 2014 - 2016.
#
#     5) Burglary
#     - Merupakan kejahatan kelima yang paling banyak terjadi sepanjang tahun 2008 - 2016 di London.
#     - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Burglary mencapai 1.043.604 kasus.
#     - Berdasarkan grafik,diperoleh hasil bahwa kejahatan Burglary turun melandai sepanjang tahun 2008 - 2016, grafik
#       Burglary bisa dipilang paling mendekati konstan dibanding grafik kejahatan lainnya.
#
# ----------------------------------------------------
# **2. Kota mana saja yang mengalami top 5 major category namun dengan jumlah paling sedikit di tahun 2013?**
#
#     1) Theft and Handling
#         - Rincian kota-kota dengan kasus Theft and Handling, 5 terendah diantaranya adalah sebagai berikut.
# |City|Counted|
#         |:-------|:------|
#         |Bexley|4293|
#         |Sutton|4173|
#         |Kingston upon Thames|4161|
#         |Harrow|4057|
#         |City of London|79|
#
#
#     2) Violence Against the Person
#          - Rincian kota-kota dengan kasus Violence Against the Person, 5 terendah diantaranya adalah sebagai berikut.
# |City|Counted|
#     |:-------|:------|
#     |Merton|2464|
#     |Sutton|2375|
#     |Kingston upon Thames|2045|
#     |Richmond upon Thames|1910|
#     |City of London|14|
#
#
#     3) Criminal Damage
#          - Rincian kota-kota dengan kasus Criminal Damage, 5 terendah diantaranya adalah sebagai berikut.
# |City|Counted|
#     |:-------|:------|
#     |Richmond upon Thames|1147|
#     |Harrow|1134|
#     |Kingston upon Thames|947|
#     |Kensington and Chelsea|824|
#     |City of London|3|
#
#
#     4) Drugs
#          - Rincian kota-kota dengan kasus Drugs, 5 terendah diantaranya adalah sebagai berikut.
# |City|Counted|
#     |:-------|:------|
#     |Merton|638|
#     |Richmond upon Thames|628|
#     |Kingston upon Thames|588|
#     |Sutton|477|
#     |City of London|4|
#
#
#     5) Burglary
#          - Rincian kota-kota dengan kasus Burglary, 5 terendah diantaranya adalah sebagai berikut.
# |City|Counted|
#     |:-------|:------|
#     |Kensington and Chelsea  |  1754|
#     |Hammersmith and Fulham   | 1514|
#     |Sutton                   | 1427|
#     |Kingston upon Thames      |1190|
#     |City of London              | 3|
#
# ----------------------------------------------------
# **3. Berapa persentase kejahatan yang paling banyak terjadi di kota Merton pada tahun 2010? Tampilkan juga visual kota Merton!**
#
#     1) Theft and Handling
#         - Merupakan kejahatan yang paling banyak terjadi pada tahun 2010 di kota Merton.
#         - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Theft and Handling mencapai 5.228 kasus.
#         - Berdasarkan pie chart, diperoleh hasil bahwa kejahatan Theft and Handling sebesar 40,4%.
#
#     2) Violence Against the Person
#         - Merupakan kejahatan kedua yang paling banyak terjadi pada tahun 2010 di kota Merton.
#         - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Theft and Handling mencapai 2.899 kasus.
#         - Berdasarkan pie chart, diperoleh hasil bahwa kejahatan Theft and Handling sebesar 22,4%.
#
#     3) Burglary
#         - Merupakan kejahatan ketiga yang paling banyak terjadi pada tahun 2010 di kota Merton.
#         - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Theft and Handling mencapai 2.069 kasus.
#         - Berdasarkan pie chart, diperoleh hasil bahwa kejahatan Theft and Handling sebesar 16,0%.
#
#     4) Criminal Damage
#         - Merupakan kejahatan keempat yang paling banyak terjadi pada tahun 2010 di kota Merton.
#         - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Theft and Handling mencapai 1.808 kasus.
#         - Berdasarkan pie chart, diperoleh hasil bahwa kejahatan Theft and Handling sebesar 14,0%.
#
#     5) Drugs
#         - Merupakan kejahatan kelima yang paling banyak terjadi pada tahun 2010 di kota Merton.
#         - Berdasarkan hasil count diawal, diperoleh hasil bahwa kejahatan Theft and Handling mencapai 921 kasus.
#         - Berdasarkan pie chart, diperoleh hasil bahwa kejahatan Theft and Handling sebesar 7,1%.
#
#         Hasil visual kota Merton berupa maps kota Merton, London. Maps tersebut dapat di zoom in dan zoom out sesuai
#         kebutuhan. Untuk lebih jelasnya dapat dilihat pada pembahasan nomor 3 ini.
#
# ----------------------------------------------------
# **4. Bagaimana perbandingan banyak kejahatan 'Criminal Damage' di kota Wandsworth dan Greenwich pada tahun 2008 - 2016?**
#
# Perbandingan banyaknya kejahatan Criminal Damage di kota Wandsworth dan Greenwich pada tahun 2008-2016:
#
#     1) Criminal Damage in Wandsworth
#         - Berdasarkan Box plot (vertikan dan horizontal), diketahui bahwa jumlah kejahatan Criminal Damage di kota
#           Wandsworth lebih sedikit dibanding jumlah kejahatan Criminal Damage di kota Greenwich sepanjang tahun 2008-2016.
#           Hal ini dapat diketahui sesuai dengan posisi box plot di kota Wandswort yang lebih rendah dibanding box plot di
#           kota Greenwich. Garis hijau menandakan rata-rata dari criminal damage in Wandsworth, yaitu sebanyak 2.181 kasus.
#         - Berdasarkan Histogram (vertikal dan horizontal), diketahui bahwa **Number of years** merupakan jumlah tahunnya,
#           dan **Number of counted** merupakan jumlah kejahatan Criminal Damage yang terjadi, sehingga:
#
# |Jumlah Tahun|Jumlah kejahatan Criminal Damage di Wandsworth|
#     |:-------|:------|
#     |3|1.700 - 1.900 kasus|
#     |1|2.500 - 2.700 kasus|
#     |2|2.700 - 2.900 kasus|
#
#         - Dengan total kasus Criminal Damage terbanyak sebesar 2.857 kasus, dan terendah sebanyak 1.836 kasus.
#
#
#     2) Criminal Damage in Greenwich
#         - Berdasarkan Box plot (vertikan dan horizontal), diketahui bahwa jumlah kejahatan Criminal Damage di kota
#           Greenwich lebih banyak dibanding jumlah kejahatan Criminal Damage di kota Wandsworth sepanjang tahun 2008-2016.
#           Hal ini dapat diketahui sesuai dengan posisi box plot di kota Greenwich yang lebih tinggi dibanding box plot di
#           kota Wandsworth. Garis hijau menandakan rata-rata dari criminal damage in Greenwich, yaitu sebanyak 2.528 kasus.
#         - Berdasarkan Histogram (vertikan dan horizontal), diketahui bahwa **Number of years** merupakan jumlah tahunnya,
#           dan **Number of counted** merupakan jumlah kejahatan Criminal Damage yang terjadi, sehingga:
#
# |Jumlah Tahun|Jumlah kejahatan Criminal Damage di Greenwich|
#     |:-------|:------|
#     |2|1.900 - 2.100 kasus|
#     |1|2.100 - 2.400 kasus|
#     |2|2.400 - 2.500 kasus|
#     |1|2.700 - 2.900 kasus|
#     |1|3.100 - 3.300 kasus|
#
#         - Dengan total kasus Criminal Damage terbanyak sebesar 3.353 kasus, dan terendah sebanyak 2.476 kasus.
#
#
# ----------------------------------------------------
# **5. Berapakah total Top 5 major crime setiap tahunnya?**
#
# |Year|Counted|Rank (Tertinggi)|
# |:-------|:------|:------|
# |2008| 692.304 | 2 |
#     |2009| 677.002 | 5 |
#     |2010| 672.215 | 7 |
#     |2011| 677.972 | 4 |
#     |2012| 691.394 | 3 |
#     |2013| 646.259 | 8 |
#     |2014| 644.996 | 9 |
#     |2015| 676.012 | 6 |
#     |2016| 697.784 | 1 |
#
# ----------------------------------------------------
# **6. Bagaimana visualisasi kota-kota dengan tingkat kejahatan tertinggi di London menggunakan Word Cloud?**
#
# Dapat dilihat bahwa kota dengan font paling besar (menandakan kota tersebut memiliki tingkat kejahatan yang tinggi), diantaranya adalah sebagai berikut.
#
#     1) Thames
#     2) Tower Hamlets
#     3) Waltham Forest
#     4) Richmond upon
#     5) Kingston upon
