# %% [markdown]
# # 01 Introduction to Python for Data Science
#
# |title||Description|
# |-----| |----|
# |Complexity Level|	|Beginner (Pemula)|
# |Prerequisite| |Untuk mengambil program ini, pastikan kamu telah memahami kemampuan dasar komputer (web browsing, app installation, file navigating). Tidak diperlukan pengalaman pemrograman atau pengembangan aplikasi web apa pun sebelumnya.|
# |Program Description| |Intro to Python for Data Science berisi semua hal dasar yang dibutuhkan untuk menjadi seorang Data Scientist. Program berbasis keterampilan ini ditujukan untuk learner, yang ingin belajar python dan ingin menerapkan statistik, machine learning, dan visualisasi informasi melalui toolkit python populer seperti pandas, matplotlib, scikit-learning, seaborn, dan banyak lagi untuk mendapatkan wawasan tentang data yang ada. Dan pada course yang terakhir learner akan belajar semua hal tentang Machine Learning yang akan mendukung kemampuan learner di bidang Data Science. Diharapkan setelah mengikuti Online Program ini learner akan menjadi seorang Data Scientist yang siap menghadapi dunia kerja di bidang Data Science.|
# |Program Objectives| |● Menggunakan fungsionalitas serta fitur dari Python yang digunakan untuk data science ● Memahami Practical Statistics yang digunakan untuk data science ● Query struktur DataFrame untuk cleaning and processing dataset ● Membuat visualisasi basic hingga advance untuk representasi data ● Membuat ML features yang memenuhi kebutuhan analisa data ● Menggunakan scikit-learn untuk membuat dan evaluasi ML model ● Mengimplementasikan Supervised dan Unsupervised Learning untuk memecahkan kasus nyata ● Mampu melakukan deployment Model ML yang telah dibuat|
# |Program Output and Portfolio type|	|Lulusan program ini diharapkan mampu melakukan EDA (Exploratory Data Analysis ) dengan Python dan mampu membuat Machine Learning Model untuk memecahkan kasus nyata.|

# %% [markdown]
# link Markdown Cheatsheet https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#code
#
# Minimum device requirements: Processor Core i3 gen 6 / Ryzen gen 1 (recommended: Core i5 gen 6 / Ryzen gen 2), RAM minimum 4GB (recommended: 8GB) and at least 100GB storage available. Preferably using Unix or Linux as an Operating System, or Windows 10 with WSL2 Ubuntu 18.04/20.04 Kernel.
#
# Contents
#
# This section covers what you'll learn in this labs.
#
# 1. Introduction: Basic Syntax, Data Type, and Variable
#     - Self Paced Learning: Memahami Jupyter Notebook
# 2. Conditions, Control Flow & Looping
# 3. Function, Basic Module, and Package
# 4. Numpy
# 5. Pandas Introduction
# 6. Data Cleaning with Pandas
# 7. Basic Visualization
# 8. Advanced Visualization
#     - Assignment Python 1
# 9. Descriptive Statistics
# 10. Inferential Statistics
#     - Assignment Python 2
# 11. Regression Models
#     - Self Paced Learning: Algoritma Machine Learning
# 12. Classification 1
# 13. Classification 2
#     - Assignment 3 Python
# 14. Unsupervised
# 15. Model Deployment
#     - Self Paced Learning: Mempelajari Machine Learning dengan Python
# 16. Final Projects
#     - Final Project
#     - Anaconda (Juypter Notebook)
#     - Visual Studio Code
#     - Google Colab
#     - Pycharm
#     - Git Scm
#     - Register Github
#     - Register Heroku (berbayar)
#
# ### Install Anaconda
# https://docs.anaconda.com/anaconda/install/
#
# ### Install Visual Studio
# https://code.visualstudio.com/
#
# ### Introduction to Python
# Apa itu Python ?
#
# "Python is Powerfull, easy to use , Object Oriented Programming language"
#
# Powerfull : bisa berjalan di semua os dan sangat berguna.
#
# Python sangat berguna : Scripts & Program (Automation, Tools) , Web Development ( django, flask , fastapi) , Data Science
#
# FastAPI : https://fastapi.tiangolo.com/
#
# Flask : https://flask.palletsprojects.com/en/2.0.x/
#
# Django : https://www.djangoproject.com/
#
# Streamlit https://streamlit.io/
#
#
# # Alur Pemrogramman
# ![Gambar%2020.png](attachment:Gambar%2020.png)

# %% [markdown]
# # Intrepeter or Compiler ?
# ![Gambar%2021.png](attachment:Gambar%2021.png)

# %% [markdown]
# ![Gambar%2022.png](attachment:Gambar%2022.png)

# %% [markdown]
# ## Menjalankan Jupyter Notebook :
# 1. Anaconda Navigator
#     - Install Juypter Notebook
#     - Open Juypter Notebook
#
# 2. Juypter Notebook command prompt
#     - Masuk ke terminal / command prompt
#     - jalankan printah command "jupyter notebook"
#
# 3. Melalui Visual Studio Code Editor
#     - buat file new dengan extension ipynb contoh : latihan.ipynb
#     - maka akan mendeteksi untuk menginstall extension jupyter
#     - atau bisa langsung cari di marketplace pada visual studio code
#
# 4. Melalui Google Colabs
#     - https://colabs.google.com
#
# ## Short Cut Jupyter
# While in command mode (press Esc to activate):
#
# Enter take you into edit mode
# - H show all shortcuts
# - Up select cell above
# - Down select cell below
# - Shift + Up extend selected cells above
# - Shift + Down extend selected cells below
# - A insert cell above
# - B insert cell below
# - X cut selected cells
# - C copy selected cells
# - V paste cells below
# - Shift + V paste cells above
# - D, D (press the key twice) delete selected cells
# - Z undo cell deletion
# - S Save and Checkpoint
# - Y change the cell type to Code
# - M change the cell type to Markdown
# - P open the command palette.
# - Shift + Space scroll notebook up
# - Space scroll notebook down
# - While in edit mode (pressEnter to activate)
#
# Esc take you into command mode Tab code completion or indent
# - Shift + Tab tooltip
# - Ctrl + ] indent
# - Ctrl + [ dedent
# - Ctrl + A select all
# - Ctrl + Z undo
# - Ctrl + Shift + Z or Ctrl + Y redo
# - Ctrl + Home go to cell start
# - Ctrl + End go to cell end
# - Ctrl + Left go one word left
# - Ctrl + Right go one word right
# - Ctrl + Shift + P open the command palette
# - Down move cursor down

# %% [markdown]
# # Introduction, Data Types, and Variables
# ### Tipe Data Python
# - Integers
# - Floating
# - String
# - Boolean

# %% [markdown]
# # Integer

# %%
print(1+2)
print(1+1)
print(1111111111111111111111111111111111111111111111+1)
# Out:
# 3
# 2
# 1111111111111111111111111111111111111111111112

# %%
number = 10 
print(number)
print(type(number))
# Out:
# 10
# <class 'int'>

# %% [markdown]
# # Floating point
# - Ada digit decimal
# - Karater E atau e

# %%
fnumber = 7. 
print(fnumber)
print(type(fnumber))
# Out:
# 7.0
# <class 'float'>

# %%
fnumber2 = .123333e7 
print(fnumber2)
print(type(fnumber2))
# Out:
# 1233330.0
# <class 'float'>

# %% [markdown]
# # String
# - Menggunakan kutip (satu (' ') atau dua (" "))

# %%
nama = 'IKetut 1 gunawan'
print(nama)
print(type(nama))
# Out:
# IKetut 1 gunawan
# <class 'str'>

# %% [markdown]
# # Boolean
# - True dan False

# %%
ok = True
print(ok)
print(type(ok))
# Out:
# True
# <class 'bool'>

# %%
ok = False
print(ok)
print(type(ok))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# # Variable Assignment

# %%
a = b = c = d = e = f = g = h = i = j = 150

# %%
print(a,b,c,d,e,f,g,h)
# Out:
# 150 150 150 150 150 150 150 150

# %% [markdown]
# ### Aturan variable names
# - Variable tidak di depan dengan menggunakan angka
# - Variable depan bisa menggunakan huruf (besar / kecil )
# - Variable depan menggunakan tanda / karakter garis bawah (_)

# %%
_ = "Kosong" 
print(_)
# Out:
# Kosong

# %%
_1 = 1 
print(_1)
# Out:
# 1

# %%
nama_depan = "IKetut"
print (nama_depan)
# Out:
# IKetut

# %%
1_angka = 10 
print(1_angka)
# Out:
#   File "C:\Users\Fransisca Mulya Sari\AppData\Local\Temp\ipykernel_10844\4143167534.py", line 1
#     1_angka = 10
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ### Standard penamaan suatu variable
# - Snake Case : first_name
# - Camel Case : jumlahAnakLakiLaki
# - Pascal case : FistName

# %% [markdown]
# # Operator dan Expresion
# Basic Arithmetic operation

# %% [markdown]
# |Operator|	|Description|	|Syntax|
# |----| |----| |----|
# |+|	|Addition: adds two operands|	|x + y|
# |–|	|Subtraction: subtracts two operands||x – y|
# |*|	|Multiplication: multiplies two operands||x * y|
# |/|	|Division (float): divides the first operand by the second||	x / y|
# |//|	|Division (floor): divides the first operand by the second||	x // y	|
# |%|	|Modulus: returns the remainder when first operand is divided by the second||	x % y|
# |**|	|Power : Returns first raised to power second||	x ** y|

# %%
x = 5 
y = 10 

print(x+y)
print(y-x)

print(y/x)
print(y//x)
print(y % x)
print(y ** 2)
# Out:
# 15
# 5
# 2.0
# 2
# 0
# 100

# %% [markdown]
# # Operator Penugasan

# %% [markdown]
# |Operator|	|Simbol|
# |----| |---|
# |Pengisian||=|
# |Penjumlahan||+=|
# |Pengurangan||-=|
# |Perkalian||*=|
# |Pembagian||/=|
# |Sisa Bagi||%=|
# |Pemangkatan||**=|

# %%
x = 10 
y = 5 

print(x+y)
y +=x    #  y = y + x 
print(y)
# Out:
# 15
# 15

# %% [markdown]
# # Comparison Operators
# - Membandingkan dua nilai
# - Dengan operator relasi

# %% [markdown]
# |Operator||Simbol|
# |---| |---|
# |Lebih Besar||>|
# |Lebih Kecil||<|
# |Sama Dengan||==|
# |Tidak Sama dengan||!=|
# |Lebih Besar Sama dengan||>=|
# |Lebih Kecil Sama dengan||<=|

# %%
x = 20 
y = 40 

print(x == y)
# Out:
# False

# %% [markdown]
# # Operator Logika
# ### operasi logika ( AND , OR , NOT )

# %% [markdown]
# |Nama||Simbol di Python|
# |----||-------|
# |Logika AND||and|
# |Logika OR||or|
# |Negasi/kebalikan||not|

# %% [markdown]
# ### Contoh : "and"

# %% [markdown]
# |x and y|	|result|
# |---| |----|
# |True and True|	|True|
# |True and False|	|False|
# |False and False|	|False|

# %% [markdown]
# ### Contoh : "or"

# %% [markdown]
# |x or y|	|result|
# |---| |---|
# |True or True|	|True|
# |True or False|	|True|
# |False or True|	|True|
# |False or False| |False|

# %%
a = True
b = False

print(a and b) # false 
print(a or b) # false
# Out:
# False
# True

# %% [markdown]
# # String manipulation

# %%
# Operator 

s = "Hai "
b = "Hello "
c = "Hola "

print(s + b + c)
# Out:
# Hai Hello Hola

# %%
hai = "Apakabar"
print(hai * 10)

print("="* 80)

print(hai in 'Apakabar Jakart?')
# Out:
# ApakabarApakabarApakabarApakabarApakabarApakabarApakabarApakabarApakabarApakabar
# ================================================================================
# True

# %%
'halo apa kabar ?'
# Out:
# 'halo apa kabar ?'

# %%
# Case Conversion 

x = "Google"

#lower 
print(x.lower())
#Uper
print(x.upper())
# swapcase 
print(x.swapcase())

y = "hadapi dengan senyuman"

print(y.capitalize())

print(y.title())
# Out:
# google
# GOOGLE
# gOOGLE
# Hadapi dengan senyuman
# Hadapi Dengan Senyuman

# %% [markdown]
# # Container

# %% [markdown]
# ![Gambar%204.PNG](attachment:Gambar%204.PNG)

# %%
names = ["Bowo","Joko","Budi"]
phone_book ={ "Ketut":"08121312121111", "Gunawan": "08121212121121"}

# %% [markdown]
# ![Gambar%205.png](attachment:Gambar%205.png)

# %% [markdown]
# ![Gambar%206.png](attachment:Gambar%206.png)

# %% [markdown]
# # Python List
# ### Karakteristik penting dari List Python adalah sebagai berikut:
# - Menggunakan tanda kurung siku
# - Lists di siapkan.
# - Lists dapat berisi objek sembarang.
# - Elemen Lists dapat diakses dengan indeks.
# - List dapat masukan ke kedalaman yang bebas.
# - List bisa berubah.
# - List bersifat dinamis.

# %%
names= ['budi','Joko','Jono','Jeky']
print(names)
print(type(names))
# Out:
# ['budi', 'Joko', 'Jono', 'Jeky']
# <class 'list'>

# %%
variabel_sembarang = ['Budi','Joko',100, 50.5, True]
print(variabel_sembarang)
print(type(variabel_sembarang))
# Out:
# ['Budi', 'Joko', 100, 50.5, True]
# <class 'list'>

# %%
variabel_sembarang[0]
# Out:
# 'Budi'

# %% [markdown]
# ![Gambar%207.png](attachment:Gambar%207.png)

# %%
data_list = ['foo','bar','baz','qux','quux', 'corge']
print(data_list[5])
print(data_list[-1])

print(data_list[6])
# Out:
# corge
# corge
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8228\929914687.py in <module>
#       3 print(data_list[-1])
#       4
# ----> 5 print(data_list[6])
#
# IndexError: list index out of range

# %% [markdown]
# ![Gambar%208.png](attachment:Gambar%208.png)

# %%
data_list = ['foo','bar','baz','qux','quux', 'corge']
print(data_list[0:4])


print(data_list[:4])

print(data_list[0:]) # 0 sampai akhir
# Out:
# ['foo', 'bar', 'baz', 'qux']
# ['foo', 'bar', 'baz', 'qux']
# ['foo', 'bar', 'baz', 'qux', 'quux', 'corge']

# %%
buah = ['apel','mangga','pepaya','jambu']

print('jeruk' in buah) 

print('apel' in buah)
# Out:
# False
# True

# %%
buah.append("Durian")
print(buah)
# Out:
# ['apel', 'mangga', 'pepaya', 'jambu', 'Durian']

# %%
buah.remove('pepaya')
print(buah)
# Out:
# ['apel', 'mangga', 'jambu', 'Durian']

# %%
buah.remove('manggis')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8228\616453572.py in <module>
# ----> 1 buah.remove('manggis')
#
# ValueError: list.remove(x): x not in list

# %%
buah_delete = buah.pop(2)
print(f"{buah_delete} telah di delete")
# Out:
# jambu telah di delete

# %%
buah.insert(2,"Manggis")

# %%
print(buah)
# Out:
# ['apel', 'mangga', 'Manggis', 'Durian']

# %%
buah.sort()
print(buah)
# Out:
# ['Durian', 'Manggis', 'apel', 'mangga']

# %%
buah
# Out:
# ['Durian', 'Manggis', 'apel', 'mangga']

# %%
#buah.remove('Manggis')

buah.remove('Durian')

# %%
buah.append('durian')

# %%
buah.append('mangis')

# %%
buah.append('rambutan')

# %%
buah
# Out:
# ['Manggis', 'apel', 'mangga', 'durian', 'mangis', 'rambutan']

# %%
buah.sort()

print(buah)
# Out:
# ['Manggis', 'apel', 'durian', 'mangga', 'mangis', 'rambutan']

# %% [markdown]
# # Python Tuples
# - Menggunakan kurung tutup '()' tidak bisa di rubah

# %%
buah_tuple = ('apel', 'durian', 'mangga', 'mangis', 'rambutan')
print(buah_tuple)
print(type(buah_tuple))
# Out:
# ('apel', 'durian', 'mangga', 'mangis', 'rambutan')
# <class 'tuple'>

# %%
buah_tuple[1]
# Out:
# 'durian'

# %%
x1 = x2 = x3 =('satu','dua','tiga')

# %%
print(x1, x2, x3)
# Out:
# ('satu', 'dua', 'tiga') ('satu', 'dua', 'tiga') ('satu', 'dua', 'tiga')

# %%
countdown = 1,2,3, "RUN!!!!" 
print(countdown)
print(type(countdown))
# Out:
# (1, 2, 3, 'RUN!!!!')
# <class 'tuple'>

# %% [markdown]
# # Python dictionary
# - Menggunakan {}
# - isi bisa berupa list
# - isi bisa berupa object
# - bisa berubah dan dinamis
# - Key dan Value (dapat diakses menggunakan key)
# - Key string
# - key dan value di pisahkan menggunakan titik dua ':'

# %% [markdown]
# ![Gambar%2009.PNG](attachment:Gambar%2009.PNG)

# %%
MLB_team = {
    'Colorado':'Rockies',
    'Boston':'Red Sox',
    'Minnesota':'Twins',
    'Milwauke':'Brewers',
    'Seatle':'Mariners',
}

# %%
print(MLB_team)
print(type(MLB_team))
# Out:
# {'Colorado': 'Rockies', 'Boston': 'Red Sox', 'Minnesota': 'Twins', 'Milwauke': 'Brewers', 'Seatle': 'Mariners'}
# <class 'dict'>

# %%
print(MLB_team['Boston'])

print(MLB_team['Boston '])
# Out:
# Red Sox
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8228\1341222439.py in <module>
#       1 print(MLB_team['Boston'])
#       2
# ----> 3 print(MLB_team['Boston '])
#
# KeyError: 'Boston '

# %%
person = {}
type(person)
# Out:
# dict

# %%
person['fname'] = "IKetut"
person['lname'] = "Gunawan"
person['age'] = 45 
person['pets'] = ['cats','ant']
person['skill'] = {"programming":['Java','Golang','Python','Solidity'],
                   "database":{"nosql":['MonggoDb','Neo4J'],"rdbms":['Mysql','PostgreSQL','Oracle']}}

# %%
print(person)
# Out:
# {'fname': 'IKetut', 'lname': 'Gunawan', 'age': 45, 'pets': ['cats', 'ant'], 'skill': {'programming': ['Java', 'Golang', 'Python', 'Solidity'], 'database': {'nosql': ['MonggoDb', 'Neo4J'], 'rdbms': ['Mysql', 'PostgreSQL', 'Oracle']}}}

# %%
import json 
print(json.dumps(person, sort_keys=False, indent=4))
# Out:
# {
#     "fname": "IKetut",
#     "lname": "Gunawan",
#     "age": 45,
#     "pets": [
#         "cats",
#         "ant"
#     ],
#     "skill": {
#         "programming": [
#             "Java",
#             "Golang",
#             "Python",
#             "Solidity"
#         ],
#         "database": {
#             "nosql": [
#                 "MonggoDb",
#                 "Neo4J"
#             ],
#             "rdbms": [
#                 "Mysql",
#                 "PostgreSQL",
#                 "Oracle"
#             ]
#         }
#     }
# }

# %% [markdown]
# # Set
# Set dalam bahasa pemrograman python adalah tipe data kolektif yang digunakan untuk menyimpan banyak nilai dalam satu variabel dengan ketentuan:
# - nilai anggota yang disimpan harus unik (tidak duplikat)
# - nilai anggota yang sudah dimasukkan tidak bisa diubah lagi
# - set bersifat unordered alias tidak berurut –yang artinya tidak bisa diakses dengan index.

# %%
varx = set("Helloapakabar")
print(varx)
print(type(varx))
# Out:
# {'o', 'a', 'l', 'k', 'b', 'r', 'e', 'p', 'H'}
# <class 'set'>

# %%
set([1,2,3,4])
# Out:
# {1, 2, 3, 4}

# %%
beatles = {"John","Paul","Ringo","Gorge"}
print(type(beatles))
print(beatles)

beatles.remove("John")
beatles.add("Ketut")
print(beatles)

beatles.add("Paul")
print(beatles)
# Out:
# <class 'set'>
# {'Ringo', 'Paul', 'John', 'Gorge'}
# {'Gorge', 'Paul', 'Ketut', 'Ringo'}
# {'Gorge', 'Paul', 'Ketut', 'Ringo'}

# %%
nirvana = {"Kurt","Cris","Dave"}

new_band = beatles | nirvana 
print(new_band)
# Out:
# {'Cris', 'Ketut', 'Kurt', 'Gorge', 'Ringo', 'Dave', 'Paul'}

# %%
word1 = {'A','B','C','D','E','F'}
word2 = {'C','E','A','X','Y','Z'}
print(word1 & word2)
# Out:
# {'E', 'A', 'C'}

# %%
# Selesai
