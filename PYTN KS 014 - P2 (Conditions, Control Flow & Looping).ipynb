# %% [markdown]
# # Perulangan dan Percabangan
# ## Python if else

# %% [markdown]
# ### 1. Python if Statement

# %% [markdown]
# ![Gambar%2010.png](attachment:Gambar%2010.png)

# %%
number = 10 
if number > 0 : 
    print("Angka Positif")
    print("didalam statement if")
print("luar dari if statment")
# Out:
# Angka Positif
# didalam statement if
# luar dari if statment

# %%
# inputan
transaksi = 10000
grade = 70 

### logic discount ### 
discount = 10 
if grade > 70: 
    discount = 50
### logic ###     

total_transaksi = transaksi - discount
print(total_transaksi)
# Out:
# 9990

# %% [markdown]
# ![Gambar%2011.png](attachment:Gambar%2011.png)

# %%
number = -5 
if number > 0: 
    print("angka positif")

print("di luar dari kondisi if")
# Out:
# di luar dari kondisi if

# %% [markdown]
# ### 2. Python if else stament

# %% [markdown]
# ![Gambar%2012.png](attachment:Gambar%2012.png)

# %%
#
number = 10 
if number > 0: 
    print("Angka positif")
else:
    print("Angka Negatif")





    print("diluar dari kondisi if else")
# Out:
# Angka positif

# %% [markdown]
# ![Gambar%2013.png](attachment:Gambar%2013.png)

# %%
#
number = -5 
if number > 0: 
    print("Angka positif")
else:
    print("Angka Negatif")
print("diluar dari kondisi if else")
# Out:
# Angka Negatif
# diluar dari kondisi if else

# %% [markdown]
# ### 3. If elif else statement

# %% [markdown]
# ![Gambar%2014.png](attachment:Gambar%2014.png)

# %%
number = 0 
if number > 0: 
    print("Angka positif")
elif number < 0:
    print("Angka Negatif")
else: 
    print("Angka 0") 
       
print("diluar dari kondisi if else")
# Out:
# Angka 0
# diluar dari kondisi if else

# %%
## if stament 
if condition1: 
    #statement pertama
    if condition2:
        # stamtent kedua 
        if condition3:
            # statement ketiga 
            if condition4:
                # statment ke empat

# %%
nilai = 59 
absen = 8
sopan = True

if nilai < 60: 
    print("dipertimbangkan")
    if absen < 7:
        print("Lulus dengan pertimbangan")
    else:
        if sopan: 
            print("Karena bebuat baik, maka lulus")
        else:    
            print("Tidak lulus")    
else:
    print("Lulus")
# Out:
# dipertimbangkan
# Karena bebuat baik, maka lulus

# %%
x=7 
y=6
i = 2 
j = 3
if 'foo' in ['foo','bar','baz']:
    print("foo ditemukan")
    
    if x > y :
        print("Nilai x lebih besar dari Y")
    
    print("kondision foo in list")
    
    if i < j:
        print("Nilai i lebih besar dari j")
        
    print("stament terakhir if")
print("Selesai")
# Out:
# foo ditemukan
# Nilai x lebih besar dari Y
# kondision foo in list
# Nilai i lebih besar dari j
# stament terakhir if
# Selesai

# %% [markdown]
# ### Python Tenary Operation
# #### If else

# %%
print("Hello saya benar") if "h" in "Helllooooo" else print("Hello kondisi salah")
# Out:
# Hello kondisi salah

# %%
raining = True 

print("Let's go to the ...", "beach" if not  raining else "Library")
# Out:
# Let's go to the ... Library

# %%
umur = 10 
status_vaksin = "belum boleh vaksin" if umur < 5 else "Sudah bisa vaksin"

print(status_vaksin)
# Out:
# Sudah bisa vaksin

# %% [markdown]
# # Python for loop

# %% [markdown]
# ![Gambar%2015.png](attachment:Gambar%2015.png)

# %%
languages = ['Golang','Python','Java','C#','Rust','Vlang']
print(languages)


for lang in languages:
    print("Bahasa pemrograman ")
    print(lang)
# Out:
# ['Golang', 'Python', 'Java', 'C#', 'Rust', 'Vlang']
# Bahasa pemrograman
# Golang
# Bahasa pemrograman
# Python
# Bahasa pemrograman
# Java
# Bahasa pemrograman
# C#
# Bahasa pemrograman
# Rust
# Bahasa pemrograman
# Vlang

# %%
mahasiswa = {"Nim":"1234567","Nama":"IKetut Gunawan","Nilai":90}

for mhs in mahasiswa:
    print(mhs)
    print(mahasiswa[mhs])
# Out:
# Nim
# 1234567
# Nama
# IKetut Gunawan
# Nilai
# 90

# %%
for k , v in mahasiswa.items():
    print(k , ":", v)
# Out:
# Nim : 1234567
# Nama : IKetut Gunawan
# Nilai : 90

# %%
values = range(5)
print(values)
for x in values:
    print(x)
# Out:
# range(0, 5)
# 0
# 1
# 2
# 3
# 4

# %%
for x in (0,1,2,3,4):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
angka = range(10)

for i in angka:
    if i % 2 == 0 :
        print(i , "Genap")
    else: 
        print(i,"Ganjil")
# Out:
# 0 Genap
# 1 Ganjil
# 2 Genap
# 3 Ganjil
# 4 Genap
# 5 Ganjil
# 6 Genap
# 7 Ganjil
# 8 Genap
# 9 Ganjil

# %%
digits = [0, 1, 2, 3, 4, 5]

for i in digits:
    print(i)
else :
    print ("No item left")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# No item left

# %% [markdown]
# # Altering for loop behavior
# - Break
# - Continue
# - Pass
# - Else

# %% [markdown]
# ![Gambar%2016.png](attachment:Gambar%2016.png)

# %% [markdown]
# ![Gambar%2017.png](attachment:Gambar%2017.png)

# %%
for i in range(5):
    print("Loop in  range")
    if i == 3:
        break
    
    print("Cetak angka ke ",i)
# Out:
# Loop in  range
# Cetak angka ke  0
# Loop in  range
# Cetak angka ke  1
# Loop in  range
# Cetak angka ke  2
# Loop in  range

# %%
i = 1
for varlist  in ['foo','bar','baz','qmux']:
    print(varlist)
    if 'z' in varlist:
        break
    
    print(i)
    i +=1
    
print(i)
# Out:
# foo
# 1
# bar
# 2
# baz
# 3

# %% [markdown]
# ![Gambar%2018.png](attachment:Gambar%2018.png)

# %%
for varlist  in ['foo','bar','baz','qmux']:
    print(varlist)
    if 'r' in varlist:
        print("r ditemukan")
        continue
    
    print("Kondisi dibawah continue")
    
print("Selesai")
# Out:
# foo
# Kondisi dibawah continue
# bar
# r ditemukan
# baz
# Kondisi dibawah continue
# qmux
# Kondisi dibawah continue
# Selesai

# %%
i = 1 
n =5 
while i <= n:
    print(i)
    i +=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
counter = 1
while counter < 4:
    print("didalam while")
    counter += 1
else:
    print("inside while else")
# Out:
# didalam while
# didalam while
# didalam while
# inside while else

# %%
x = ['cat','dog']

while len(x):
    print(x.pop(0))
    
    y = ['gug','meow']
    
    while(len(y)):
        print('>', y.pop(0))
# Out:
# cat
# > gug
# > meow
# dog
# > gug
# > meow

# %%
# one line while
x = 4
while x > 0:  x -=1; print(x)
# Out:
# 3
# 2
# 1
# 0

# %%
while True: 
    msg = input("Ketikan karakter :")
    print(msg)
    
    if msg == "stop":
        break
# Out:
# Ketikan karakter :Halo
# Halo
# Ketikan karakter :Hai
# Hai
# Ketikan karakter :stop
# stop

# %%
def SwitchExamples(args):
    switch = {
        0 : "Angka Nol",
        1 : "Angka Satu",
        2 : "Angka 2"
    }
    return switch.get(args, "Nothing" )

# %%
hasil = SwitchExamples(0)
print(hasil)
# Out:
# Angka Nol

# %%
hasil = 0 
temp = input("Ketik temparatur yang ingin di konversi eg. 40F, 18C, 0C: ")

print(type(temp))
print(temp)
degree = int(temp[:-1])
print("degree : ",degree)
print(f"format degree : {degree} ")

convertion = temp[-1]
print("Convertion : ",convertion)

if convertion == 'C':
    print("Celcius")
    hasil = int(round(9 * degree) / 5 + 32)
elif convertion == 'F':
    print("F")
    hasil = int(round(degree - 32) * 5 / 9 )
else: 
    print("Yang anda input salah")
    
print("Tempartur adalah : ", hasil, "derajat")
# Out:
# Ketik temparatur yang ingin di konversi eg. 40F, 18C, 0C: 18C
# <class 'str'>
# 18C
# degree :  18
# format degree : 18
# Convertion :  C
# Celcius
# Tempartur adalah :  64 derajat

# %%
for x in range(1,6):
    for y in range(x):
        print('*', end=' ')
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
# Selesai
